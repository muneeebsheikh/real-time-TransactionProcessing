# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window
import pandas as pd
import time
from datetime import datetime, timedelta
import random
from pyspark.sql.functions import col, count, sum, avg, max, min, desc, year, month, dayofweek, hour, datediff, lit, when, countDistinct, ntile

# %%
spark = SparkSession.builder \
    .appName("RealTimeRetailAnalytics") \
    .config("spark.sql.shuffle.partitions", "4") \
    .config("spark.driver.memory", "4g") \
    .getOrCreate()

print("✓ Spark Session initialized")
print(f"Spark Version: {spark.version}\n")
# Out:
# ✓ Spark Session initialized
# Spark Version: 4.0.1

# %%
# !wget -q https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx

# %%
df_pandas = pd.read_excel('Online Retail.xlsx')
df_pandas['InvoiceDate'] = pd.to_datetime(df_pandas['InvoiceDate'])

# %%
df_cleaned = df_pandas[
    (df_pandas['CustomerID'].notna()) &
    (df_pandas['Quantity'] > 0) &
    (df_pandas['UnitPrice'] > 0)
].copy()

# %%
df_cleaned['TotalPrice'] = df_cleaned['Quantity'] * df_cleaned['UnitPrice']

# %%
print(f"Original records: {len(df_pandas)}")
print(f"Cleaned records: {len(df_cleaned)}")
print(f"Date range: {df_cleaned['InvoiceDate'].min()} to {df_cleaned['InvoiceDate'].max()}\n")
# Out:
# Original records: 541909
# Cleaned records: 397884
# Date range: 2010-12-01 08:26:00 to 2011-12-09 12:50:00

# %% [markdown]
# ## SIMULATED STREAMING DATA GENERATOR

# %%
def create_streaming_data(batch_id, num_transactions=50):
    """
    Simulate real-time transactions by sampling from historical data
    and adding current timestamps
    """
    sample = df_cleaned.sample(n=num_transactions, replace=True)

    # Add artificial timestamps to simulate real-time
    base_time = datetime.now()
    time_offsets = [timedelta(seconds=random.randint(0, 10)) for _ in range(num_transactions)]
    sample['StreamTimestamp'] = [base_time + offset for offset in time_offsets]

    return sample

# %%
sample_batch = create_streaming_data(0, 100)

# %%
sample_batch
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 198850    554071     23298                      SPOTTY BUNTING         4
# 516059    579854     23503  PLAYING CARDS KEEP CALM & CARRY ON         6
# 468199    576399     23367     SET 12 COLOUR PENCILS SPACEBOY         16
# 290415    562377     21745     GAOLERS KEYS DECORATIVE GARDEN          3
# 228988    557007     22221     CAKE STAND LOVEBIRD 2 TIER PINK         4
# ...          ...       ...                                 ...       ...
# 453666    575491     22600       CHRISTMAS RETROSPOT STAR WOOD         5
# 223501    556484     22566  FELTCRAFT HAIRBAND PINK AND PURPLE         2
# 527928    580727     23014      GLASS APOTHECARY BOTTLE ELIXIR         1
# 342850    566914     23169            CLASSIC GLASS COOKIE JAR         1
# 491949    578082     22831            WHITE BROCANTE SOAP DISH         6
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 198850 2011-05-22 11:17:00       4.95     13113.0  United Kingdom       19.80
# 516059 2011-11-30 16:26:00       1.25     14713.0  United Kingdom        7.50
# 468199 2011-11-15 10:50:00       0.65     12684.0          France       10.40
# 290415 2011-08-04 15:04:00       3.75     14535.0  United Kingdom       11.25
# 228988 2011-06-16 11:30:00       9.95     12484.0           Spain       39.80
# ...                    ...        ...         ...             ...         ...
# 453666 2011-11-09 17:47:00       0.85     15531.0  United Kingdom        4.25
# 223501 2011-06-12 13:17:00       0.85     16938.0  United Kingdom        1.70
# 527928 2011-12-05 17:17:00       8.29     14096.0  United Kingdom        8.29
# 342850 2011-09-15 14:08:00       4.15     15466.0  United Kingdom        4.15
# 491949 2011-11-22 16:33:00       2.95     12775.0     Netherlands       17.70
#
#                   StreamTimestamp
# 198850 2025-12-27 17:31:38.298265
# 516059 2025-12-27 17:31:34.298265
# 468199 2025-12-27 17:31:31.298265
# 290415 2025-12-27 17:31:32.298265
# 228988 2025-12-27 17:31:38.298265
# ...                           ...
# 453666 2025-12-27 17:31:36.298265
# 223501 2025-12-27 17:31:31.298265
# 527928 2025-12-27 17:31:33.298265
# 342850 2025-12-27 17:31:31.298265
# 491949 2025-12-27 17:31:36.298265
#
# [100 rows x 10 columns]

# %%
stream_schema = StructType([
    StructField("InvoiceNo", StringType(), True),
    StructField("StockCode", StringType(), True),
    StructField("Description", StringType(), True),
    StructField("Quantity", IntegerType(), True),
    StructField("InvoiceDate", TimestampType(), True),
    StructField("UnitPrice", DoubleType(), True),
    StructField("CustomerID", DoubleType(), True),
    StructField("Country", StringType(), True),
    StructField("TotalPrice", DoubleType(), True),
    StructField("StreamTimestamp", TimestampType(), True)
])

# %% [markdown]
# ## SLIDING WINDOW AGGREGATIONS

# %%
def process_streaming_batch(batch_df, batch_id):
    """
    Process each micro-batch with various sliding window aggregations
    """
    if batch_df.empty:
        return

    print(f"\n{'='*70}")
    print(f"BATCH {batch_id} | Time: {datetime.now().strftime('%H:%M:%S')}")
    print(f"{'='*70}")

    spark_batch = spark.createDataFrame(batch_df, schema=stream_schema)

    spark_batch = spark_batch.withColumn("event_time", col("StreamTimestamp"))

    # WINDOW 1: 30-Second Tumbling Window - Revenue Metrics
    print("\n[1] 30-Second Revenue Window:")
    revenue_window = spark_batch \
        .groupBy(window("event_time", "30 seconds")) \
        .agg(
            count("*").alias("transaction_count"),
            sum("TotalPrice").alias("total_revenue"),
            avg("TotalPrice").alias("avg_transaction_value"),
            countDistinct("CustomerID").alias("unique_customers")
        ) \
        .orderBy("window")

    revenue_window.show(truncate=False)

    # WINDOW 2: 1-Minute Sliding Window (30s slide) - Top Products
    print("\n[2] Top 5 Products (1-min window, 30s slide):")
    product_window = spark_batch \
        .groupBy(
            window("event_time", "1 minute", "30 seconds"),
            "StockCode",
            "Description"
        ) \
        .agg(
            sum("Quantity").alias("units_sold"),
            sum("TotalPrice").alias("revenue")
        )

    window_spec = Window.partitionBy("window").orderBy(desc("revenue"))
    top_products = product_window \
        .withColumn("rank", row_number().over(window_spec)) \
        .filter(col("rank") <= 5) \
        .select("window", "rank", "Description", "units_sold", "revenue")

    top_products.show(truncate=False)

    # WINDOW 3: 2-Minute Sliding Window (1m slide) - Country Analysis
    print("\n[3] Country Sales (2-min window, 1m slide):")
    country_window = spark_batch \
        .groupBy(
            window("event_time", "2 minutes", "1 minute"),
            "Country"
        ) \
        .agg(
            count("*").alias("orders"),
            sum("TotalPrice").alias("revenue"),
            avg("Quantity").alias("avg_items_per_order")
        ) \
        .orderBy(desc("revenue"))

    country_window.show(5, truncate=False)

    # WINDOW 4: Session Window - Customer Purchase Patterns
    print("\n[4] Customer Activity Summary:")
    customer_stats = spark_batch \
        .groupBy("CustomerID") \
        .agg(
            count("*").alias("transactions"),
            sum("TotalPrice").alias("total_spent"),
            collect_list("StockCode").alias("products_bought"),
            min("event_time").alias("first_purchase"),
            max("event_time").alias("last_purchase")
        )

    customer_stats = customer_stats.withColumn(
        "session_duration_sec",
        (unix_timestamp("last_purchase") - unix_timestamp("first_purchase"))
    )

    customer_stats.select(
        "CustomerID",
        "transactions",
        "total_spent",
        "session_duration_sec"
    ).orderBy(desc("total_spent")).show(10, truncate=False)

    # WINDOW 5: Real-Time Anomaly Detection
    print("\n[5] Anomaly Detection - High Value Transactions:")

    avg_price = spark_batch.agg(avg("TotalPrice")).collect()[0][0]
    stddev_price = spark_batch.agg(stddev("TotalPrice")).collect()[0][0]

    if stddev_price and stddev_price > 0:
        threshold = avg_price + (2.5 * stddev_price)

        anomalies = spark_batch.filter(col("TotalPrice") > threshold) \
            .select(
                "InvoiceNo",
                "CustomerID",
                "Description",
                "Quantity",
                "TotalPrice",
                "event_time"
            )

        anomaly_count = anomalies.count()
        if anomaly_count > 0:
            print(f"⚠ Detected {anomaly_count} high-value transactions (> ${threshold:.2f})")
            anomalies.show(5, truncate=False)
        else:
            print("✓ No anomalies detected")

    # WINDOW 6: Frequent Items in Last Minute
    print("\n[6] Trending Items (Last Minute):")

    current_time = spark_batch.agg(max("event_time")).collect()[0][0]
    if current_time:
        one_min_ago = current_time - timedelta(minutes=1)

        recent_items = spark_batch \
            .filter(col("event_time") >= lit(one_min_ago)) \
            .groupBy("Description") \
            .agg(
                count("*").alias("purchase_frequency"),
                sum("Quantity").alias("total_quantity")
            ) \
            .orderBy(desc("purchase_frequency"))

        recent_items.show(5, truncate=False)

# %% [markdown]
# ## CONTINUOUS STREAMING SIMULATION

# %%
print("\n" + "="*70)
print("STARTING REAL-TIME STREAM PROCESSING")
print("="*70)
print("Simulating 5 batches of streaming transactions...\n")
# Out:
# ======================================================================
# STARTING REAL-TIME STREAM PROCESSING
# ======================================================================
# Simulating 5 batches of streaming transactions...

# %%
num_batches = 5
transactions_per_batch = 80

# %%
for batch_id in range(num_batches):
    print(f"\n{'#'*70}")
    print(f"# Generating Batch {batch_id + 1}/{num_batches}")
    print(f"{'#'*70}")

    # Generate streaming data
    batch_data = create_streaming_data(batch_id, transactions_per_batch)

    # Process the batch
    process_streaming_batch(batch_data, batch_id)

    # Wait before next batch (simulate real-time delay)
    if batch_id < num_batches - 1:
        print("\n⏳ Waiting for next batch...")
        time.sleep(2)
# Out:
# ######################################################################
# # Generating Batch 1/5
# ######################################################################
#
# ======================================================================
# BATCH 0 | Time: 17:38:48
# ======================================================================
#
# [1] 30-Second Revenue Window:
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |window                                    |transaction_count|total_revenue     |avg_transaction_value|unique_customers|
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |{2025-12-27 17:38:30, 2025-12-27 17:39:00}|80               |1737.4200000000003|21.717750000000002   |76              |
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
#
#
# [2] Top 5 Products (1-min window, 30s slide):
# +------------------------------------------+----+----------------------------------+----------+-------+
# |window                                    |rank|Description                       |units_sold|revenue|
# +------------------------------------------+----+----------------------------------+----------+-------+
# |{2025-12-27 17:38:00, 2025-12-27 17:39:00}|1   |VINTAGE SNAP CARDS                |288       |167.04 |
# |{2025-12-27 17:38:00, 2025-12-27 17:39:00}|2   |SET OF 9 BLACK SKULL BALLOONS     |200       |144.0  |
# |{2025-12-27 17:38:00, 2025-12-27 17:39:00}|3   |RED RETROSPOT CAKE STAND          |10        |109.5  |
# |{2025-12-27 17:38:00, 2025-12-27 17:39:00}|4   |WOOD 2 DRAWER CABINET WHITE FINISH|16        |95.2   |
# |{2025-12-27 17:38:00, 2025-12-27 17:39:00}|5   |DOORMAT KEEP CALM AND COME IN     |11        |79.05  |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|1   |VINTAGE SNAP CARDS                |288       |167.04 |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|2   |SET OF 9 BLACK SKULL BALLOONS     |200       |144.0  |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|3   |RED RETROSPOT CAKE STAND          |10        |109.5  |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|4   |WOOD 2 DRAWER CABINET WHITE FINISH|16        |95.2   |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|5   |DOORMAT KEEP CALM AND COME IN     |11        |79.05  |
# +------------------------------------------+----+----------------------------------+----------+-------+
#
#
# [3] Country Sales (2-min window, 1m slide):
# +------------------------------------------+--------------+------+-------+-------------------+
# |window                                    |Country       |orders|revenue|avg_items_per_order|
# +------------------------------------------+--------------+------+-------+-------------------+
# |{2025-12-27 17:37:00, 2025-12-27 17:39:00}|United Kingdom|70    |1359.32|17.32857142857143  |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|United Kingdom|70    |1359.32|17.32857142857143  |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|Netherlands   |1     |144.0  |200.0              |
# |{2025-12-27 17:37:00, 2025-12-27 17:39:00}|Netherlands   |1     |144.0  |200.0              |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|Spain         |2     |118.2  |8.0                |
# +------------------------------------------+--------------+------+-------+-------------------+
# only showing top 5 rows
#
# [4] Customer Activity Summary:
# +----------+------------+------------------+--------------------+
# |CustomerID|transactions|total_spent       |session_duration_sec|
# +----------+------------+------------------+--------------------+
# |12830.0   |1           |167.04            |0                   |
# |14646.0   |1           |144.0             |0                   |
# |12540.0   |1           |109.5             |0                   |
# |17975.0   |1           |95.2              |0                   |
# |16912.0   |1           |76.5              |0                   |
# |13536.0   |1           |70.8              |0                   |
# |18222.0   |1           |51.0              |0                   |
# |18139.0   |1           |50.400000000000006|0                   |
# |16814.0   |1           |47.7              |0                   |
# |18072.0   |1           |46.8              |0                   |
# +----------+------------+------------------+--------------------+
# only showing top 10 rows
#
# [5] Anomaly Detection - High Value Transactions:
# ⚠ Detected 3 high-value transactions (> $95.47)
# +---------+----------+-----------------------------+--------+----------+--------------------------+
# |InvoiceNo|CustomerID|Description                  |Quantity|TotalPrice|event_time                |
# +---------+----------+-----------------------------+--------+----------+--------------------------+
# |564650   |14646.0   |SET OF 9 BLACK SKULL BALLOONS|200     |144.0     |2025-12-27 17:38:52.552959|
# |547703   |12540.0   |RED RETROSPOT CAKE STAND     |10      |109.5     |2025-12-27 17:38:57.552959|
# |561671   |12830.0   |VINTAGE SNAP CARDS           |288     |167.04    |2025-12-27 17:38:49.552959|
# +---------+----------+-----------------------------+--------+----------+--------------------------+
#
#
# [6] Trending Items (Last Minute):
# +---------------------------------+------------------+--------------+
# |Description                      |purchase_frequency|total_quantity|
# +---------------------------------+------------------+--------------+
# |ROSES REGENCY TEACUP AND SAUCER  |2                 |14            |
# |SPACEBOY LUNCH BOX               |2                 |14            |
# |DOORMAT KEEP CALM AND COME IN    |2                 |11            |
# |TRADITIONAL MODELLING CLAY       |2                 |28            |
# |WOOD BLACK BOARD ANT WHITE FINISH|2                 |9             |
# +---------------------------------+------------------+--------------+
# only showing top 5 rows
#
# ⏳ Waiting for next batch...
#
# ######################################################################
# # Generating Batch 2/5
# ######################################################################
#
# ======================================================================
# BATCH 1 | Time: 17:39:11
# ======================================================================
#
# [1] 30-Second Revenue Window:
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |window                                    |transaction_count|total_revenue     |avg_transaction_value|unique_customers|
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |{2025-12-27 17:39:00, 2025-12-27 17:39:30}|80               |1542.6800000000003|19.283500000000004   |79              |
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
#
#
# [2] Top 5 Products (1-min window, 30s slide):
# +------------------------------------------+----+------------------------------+----------+------------------+
# |window                                    |rank|Description                   |units_sold|revenue           |
# +------------------------------------------+----+------------------------------+----------+------------------+
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|1   |BOX OF VINTAGE ALPHABET BLOCKS|24        |238.79999999999998|
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|2   |HAPPY STENCIL CRAFT           |96        |101.76            |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|3   |RED  HARMONICA IN BOX         |50        |62.5              |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|4   |JUMBO BAG RED RETROSPOT       |30        |62.400000000000006|
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|5   |BREAD BIN DINER STYLE IVORY   |4         |59.8              |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|1   |BOX OF VINTAGE ALPHABET BLOCKS|24        |238.79999999999998|
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|2   |HAPPY STENCIL CRAFT           |96        |101.76            |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|3   |RED  HARMONICA IN BOX         |50        |62.5              |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|4   |JUMBO BAG RED RETROSPOT       |30        |62.400000000000006|
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|5   |BREAD BIN DINER STYLE IVORY   |4         |59.8              |
# +------------------------------------------+----+------------------------------+----------+------------------+
#
#
# [3] Country Sales (2-min window, 1m slide):
# +------------------------------------------+--------------+------+------------------+-------------------+
# |window                                    |Country       |orders|revenue           |avg_items_per_order|
# +------------------------------------------+--------------+------+------------------+-------------------+
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|United Kingdom|69    |1291.5500000000002|9.028985507246377  |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|United Kingdom|69    |1291.5500000000002|9.028985507246377  |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|Belgium       |3     |87.60000000000001 |14.0               |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|Belgium       |3     |87.60000000000001 |14.0               |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|Australia     |1     |39.599999999999994|24.0               |
# +------------------------------------------+--------------+------+------------------+-------------------+
# only showing top 5 rows
#
# [4] Customer Activity Summary:
# +----------+------------+------------------+--------------------+
# |CustomerID|transactions|total_spent       |session_duration_sec|
# +----------+------------+------------------+--------------------+
# |17929.0   |1           |238.79999999999998|0                   |
# |17381.0   |1           |101.76            |0                   |
# |15625.0   |1           |60.0              |0                   |
# |15067.0   |1           |59.8              |0                   |
# |15825.0   |1           |58.0              |0                   |
# |12449.0   |1           |49.800000000000004|0                   |
# |12921.0   |1           |41.6              |0                   |
# |12388.0   |1           |39.599999999999994|0                   |
# |15379.0   |1           |38.160000000000004|0                   |
# |12412.0   |1           |36.0              |0                   |
# +----------+------------+------------------+--------------------+
# only showing top 10 rows
#
# [5] Anomaly Detection - High Value Transactions:
# ⚠ Detected 2 high-value transactions (> $94.69)
# +---------+----------+------------------------------+--------+------------------+-------------------------+
# |InvoiceNo|CustomerID|Description                   |Quantity|TotalPrice        |event_time               |
# +---------+----------+------------------------------+--------+------------------+-------------------------+
# |548316   |17929.0   |BOX OF VINTAGE ALPHABET BLOCKS|24      |238.79999999999998|2025-12-27 17:39:11.91559|
# |548704   |17381.0   |HAPPY STENCIL CRAFT           |96      |101.76            |2025-12-27 17:39:11.91559|
# +---------+----------+------------------------------+--------+------------------+-------------------------+
#
#
# [6] Trending Items (Last Minute):
# +--------------------------------+------------------+--------------+
# |Description                     |purchase_frequency|total_quantity|
# +--------------------------------+------------------+--------------+
# |RED  HARMONICA IN BOX           |2                 |50            |
# |SET OF 4 KNICK KNACK TINS DOILY |2                 |14            |
# |JUMBO BAG RED RETROSPOT         |2                 |30            |
# |RED RETROSPOT CHARLOTTE BAG     |2                 |11            |
# |STRAWBERRY SHOPPER BAG          |2                 |20            |
# +--------------------------------+------------------+--------------+
# only showing top 5 rows
#
# ⏳ Waiting for next batch...
#
# ######################################################################
# # Generating Batch 3/5
# ######################################################################
#
# ======================================================================
# BATCH 2 | Time: 17:39:21
# ======================================================================
#
# [1] 30-Second Revenue Window:
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |window                                    |transaction_count|total_revenue     |avg_transaction_value|unique_customers|
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |{2025-12-27 17:39:00, 2025-12-27 17:39:30}|63               |1801.7100000000003|28.598571428571432   |62              |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:00}|17               |271.21999999999997|15.954117647058823   |17              |
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
#
#
# [2] Top 5 Products (1-min window, 30s slide):
# +------------------------------------------+----+-----------------------------------+----------+------------------+
# |window                                    |rank|Description                        |units_sold|revenue           |
# +------------------------------------------+----+-----------------------------------+----------+------------------+
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|1   |RECIPE BOX PANTRY YELLOW DESIGN    |192       |489.59999999999997|
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|2   |LUNCH BAG SUKI DESIGN              |150       |217.5             |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|3   |POSTAGE                            |5         |90.0              |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|4   |ANTIQUE TALL SWIRLGLASS TRINKET POT|20        |75.0              |
# |{2025-12-27 17:38:30, 2025-12-27 17:39:30}|5   |SET/20 RED RETROSPOT PAPER NAPKINS |96        |69.12             |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|1   |RECIPE BOX PANTRY YELLOW DESIGN    |192       |489.59999999999997|
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|2   |LUNCH BAG SUKI DESIGN              |150       |217.5             |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|3   |MOROCCAN TEA GLASS                 |144       |93.60000000000001 |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|4   |POSTAGE                            |5         |90.0              |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|5   |ANTIQUE TALL SWIRLGLASS TRINKET POT|20        |75.0              |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|1   |MOROCCAN TEA GLASS                 |144       |93.60000000000001 |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|2   |12 COLOURED PARTY BALLOONS         |60        |39.0              |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|3   |FOLKART STAR CHRISTMAS DECORATIONS |48        |18.72             |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|4   |LARGE ANTIQUE WHITE PHOTO FRAME    |2         |15.8              |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|5   |KEY FOB , FRONT  DOOR              |24        |15.600000000000001|
# +------------------------------------------+----+-----------------------------------+----------+------------------+
#
#
# [3] Country Sales (2-min window, 1m slide):
# +------------------------------------------+--------------+------+-------+-------------------+
# |window                                    |Country       |orders|revenue|avg_items_per_order|
# +------------------------------------------+--------------+------+-------+-------------------+
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|United Kingdom|75    |1710.88|17.64              |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|United Kingdom|75    |1710.88|17.64              |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|Spain         |1     |217.5  |150.0              |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|Spain         |1     |217.5  |150.0              |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|France        |1     |90.0   |5.0                |
# +------------------------------------------+--------------+------+-------+-------------------+
# only showing top 5 rows
#
# [4] Customer Activity Summary:
# +----------+------------+------------------+--------------------+
# |CustomerID|transactions|total_spent       |session_duration_sec|
# +----------+------------+------------------+--------------------+
# |17389.0   |1           |489.59999999999997|0                   |
# |12557.0   |1           |217.5             |0                   |
# |18092.0   |1           |93.60000000000001 |0                   |
# |12682.0   |1           |90.0              |0                   |
# |14618.0   |1           |75.0              |0                   |
# |13694.0   |1           |69.12             |0                   |
# |15739.0   |1           |49.8              |0                   |
# |13871.0   |1           |47.2              |0                   |
# |15061.0   |1           |45.0              |0                   |
# |12921.0   |1           |44.25             |0                   |
# +----------+------------+------------------+--------------------+
# only showing top 10 rows
#
# [5] Anomaly Detection - High Value Transactions:
# ⚠ Detected 2 high-value transactions (> $175.92)
# +---------+----------+-------------------------------+--------+------------------+--------------------------+
# |InvoiceNo|CustomerID|Description                    |Quantity|TotalPrice        |event_time                |
# +---------+----------+-------------------------------+--------+------------------+--------------------------+
# |575683   |17389.0   |RECIPE BOX PANTRY YELLOW DESIGN|192     |489.59999999999997|2025-12-27 17:39:23.637614|
# |547972   |12557.0   |LUNCH BAG SUKI DESIGN          |150     |217.5             |2025-12-27 17:39:26.637614|
# +---------+----------+-------------------------------+--------+------------------+--------------------------+
#
#
# [6] Trending Items (Last Minute):
# +----------------------------------+------------------+--------------+
# |Description                       |purchase_frequency|total_quantity|
# +----------------------------------+------------------+--------------+
# |PICNIC BASKET WICKER LARGE        |2                 |3             |
# |TRAVEL CARD WALLET UNION JACK     |2                 |60            |
# |SET OF 72 PINK HEART PAPER DOILIES|1                 |12            |
# |BAKING SET SPACEBOY DESIGN        |1                 |2             |
# |GROW YOUR OWN HERBS SET OF 3      |1                 |1             |
# +----------------------------------+------------------+--------------+
# only showing top 5 rows
#
# ⏳ Waiting for next batch...
#
# ######################################################################
# # Generating Batch 4/5
# ######################################################################
#
# ======================================================================
# BATCH 3 | Time: 17:39:31
# ======================================================================
#
# [1] 30-Second Revenue Window:
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |window                                    |transaction_count|total_revenue     |avg_transaction_value|unique_customers|
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |{2025-12-27 17:39:30, 2025-12-27 17:40:00}|80               |1931.8500000000006|24.148125000000007   |76              |
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
#
#
# [2] Top 5 Products (1-min window, 30s slide):
# +------------------------------------------+----+-----------------------------------+----------+------------------+
# |window                                    |rank|Description                        |units_sold|revenue           |
# +------------------------------------------+----+-----------------------------------+----------+------------------+
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|1   |CREAM HEART CARD HOLDER            |216       |501.11999999999995|
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|2   |CHILDRENS CUTLERY DOLLY GIRL       |72        |270.0             |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|3   |COLOUR GLASS T-LIGHT HOLDER HANGING|144       |79.2              |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|4   |NATURAL SLATE HEART CHALKBOARD     |11        |63.69             |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|5   |GIRLS ALPHABET IRON ON PATCHES     |288       |60.48             |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|1   |CREAM HEART CARD HOLDER            |216       |501.11999999999995|
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|2   |CHILDRENS CUTLERY DOLLY GIRL       |72        |270.0             |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|3   |COLOUR GLASS T-LIGHT HOLDER HANGING|144       |79.2              |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|4   |NATURAL SLATE HEART CHALKBOARD     |11        |63.69             |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|5   |GIRLS ALPHABET IRON ON PATCHES     |288       |60.48             |
# +------------------------------------------+----+-----------------------------------+----------+------------------+
#
#
# [3] Country Sales (2-min window, 1m slide):
# +------------------------------------------+--------------+------+------------------+-------------------+
# |window                                    |Country       |orders|revenue           |avg_items_per_order|
# +------------------------------------------+--------------+------+------------------+-------------------+
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|United Kingdom|68    |1434.9199999999998|12.720588235294118 |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|United Kingdom|68    |1434.9199999999998|12.720588235294118 |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|Netherlands   |1     |270.0             |72.0               |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|Netherlands   |1     |270.0             |72.0               |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|Germany       |2     |76.08             |148.0              |
# +------------------------------------------+--------------+------+------------------+-------------------+
# only showing top 5 rows
#
# [4] Customer Activity Summary:
# +----------+------------+------------------+--------------------+
# |CustomerID|transactions|total_spent       |session_duration_sec|
# +----------+------------+------------------+--------------------+
# |18102.0   |1           |501.11999999999995|0                   |
# |14646.0   |1           |270.0             |0                   |
# |14096.0   |3           |94.12             |6                   |
# |13408.0   |1           |79.2              |0                   |
# |13815.0   |1           |60.48             |0                   |
# |17365.0   |1           |50.0              |0                   |
# |15311.0   |1           |49.92             |0                   |
# |15039.0   |1           |47.7              |0                   |
# |16019.0   |1           |39.6              |0                   |
# |12502.0   |1           |33.9              |0                   |
# +----------+------------+------------------+--------------------+
# only showing top 10 rows
#
# [5] Anomaly Detection - High Value Transactions:
# ⚠ Detected 2 high-value transactions (> $181.61)
# +---------+----------+-----------------------------+--------+------------------+--------------------------+
# |InvoiceNo|CustomerID|Description                  |Quantity|TotalPrice        |event_time                |
# +---------+----------+-----------------------------+--------+------------------+--------------------------+
# |554827   |14646.0   |CHILDRENS CUTLERY DOLLY GIRL |72      |270.0             |2025-12-27 17:39:35.949967|
# |553470   |18102.0   |CREAM HEART CARD HOLDER      |216     |501.11999999999995|2025-12-27 17:39:32.949967|
# +---------+----------+-----------------------------+--------+------------------+--------------------------+
#
#
# [6] Trending Items (Last Minute):
# +------------------------------+------------------+--------------+
# |Description                   |purchase_frequency|total_quantity|
# +------------------------------+------------------+--------------+
# |REX CASH+CARRY JUMBO SHOPPER  |2                 |3             |
# |WALL ART DOG LICENCE          |2                 |6             |
# |PACK OF 60 DINOSAUR CAKE CASES|2                 |7             |
# |CIRCUS PARADE LUNCH BOX       |1                 |4             |
# |FELT TOADSTOOL  SMALL         |1                 |2             |
# +------------------------------+------------------+--------------+
# only showing top 5 rows
#
# ⏳ Waiting for next batch...
#
# ######################################################################
# # Generating Batch 5/5
# ######################################################################
#
# ======================================================================
# BATCH 4 | Time: 17:39:41
# ======================================================================
#
# [1] 30-Second Revenue Window:
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |window                                    |transaction_count|total_revenue     |avg_transaction_value|unique_customers|
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
# |{2025-12-27 17:39:30, 2025-12-27 17:40:00}|80               |1304.1500000000003|16.301875000000003   |78              |
# +------------------------------------------+-----------------+------------------+---------------------+----------------+
#
#
# [2] Top 5 Products (1-min window, 30s slide):
# +------------------------------------------+----+---------------------------------+----------+------------------+
# |window                                    |rank|Description                      |units_sold|revenue           |
# +------------------------------------------+----+---------------------------------+----------+------------------+
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|1   |BREAD BIN DINER STYLE IVORY      |6         |93.69999999999999 |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|2   |RED HANGING HEART T-LIGHT HOLDER |32        |81.6              |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|3   |RED TOADSTOOL LED NIGHT LIGHT    |48        |79.19999999999999 |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|4   |CHRISTMAS HANGING HEART WITH BELL|48        |60.0              |
# |{2025-12-27 17:39:00, 2025-12-27 17:40:00}|5   |BOX OF 6 MINI VINTAGE CRACKERS   |24        |59.760000000000005|
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|1   |BREAD BIN DINER STYLE IVORY      |6         |93.69999999999999 |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|2   |RED HANGING HEART T-LIGHT HOLDER |32        |81.6              |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|3   |RED TOADSTOOL LED NIGHT LIGHT    |48        |79.19999999999999 |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|4   |CHRISTMAS HANGING HEART WITH BELL|48        |60.0              |
# |{2025-12-27 17:39:30, 2025-12-27 17:40:30}|5   |BOX OF 6 MINI VINTAGE CRACKERS   |24        |59.760000000000005|
# +------------------------------------------+----+---------------------------------+----------+------------------+
#
#
# [3] Country Sales (2-min window, 1m slide):
# +------------------------------------------+--------------+------+------------------+-------------------+
# |window                                    |Country       |orders|revenue           |avg_items_per_order|
# +------------------------------------------+--------------+------+------------------+-------------------+
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|United Kingdom|73    |1162.46           |8.58904109589041   |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|United Kingdom|73    |1162.46           |8.58904109589041   |
# |{2025-12-27 17:38:00, 2025-12-27 17:40:00}|Germany       |3     |103.89999999999999|23.333333333333332 |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|Germany       |3     |103.89999999999999|23.333333333333332 |
# |{2025-12-27 17:39:00, 2025-12-27 17:41:00}|France        |2     |18.5              |9.0                |
# +------------------------------------------+--------------+------+------------------+-------------------+
# only showing top 5 rows
#
# [4] Customer Activity Summary:
# +----------+------------+------------------+--------------------+
# |CustomerID|transactions|total_spent       |session_duration_sec|
# +----------+------------+------------------+--------------------+
# |14733.0   |1           |81.6              |0                   |
# |12471.0   |1           |79.19999999999999 |0                   |
# |14544.0   |1           |60.0              |0                   |
# |13098.0   |1           |59.8              |0                   |
# |15075.0   |1           |59.760000000000005|0                   |
# |13018.0   |2           |48.3              |5                   |
# |16070.0   |1           |45.0              |0                   |
# |17690.0   |1           |39.75             |0                   |
# |15482.0   |1           |36.0              |0                   |
# |15782.0   |1           |33.9              |0                   |
# +----------+------------+------------------+--------------------+
# only showing top 10 rows
#
# [5] Anomaly Detection - High Value Transactions:
# ⚠ Detected 5 high-value transactions (> $58.30)
# +---------+----------+---------------------------------+--------+------------------+--------------------------+
# |InvoiceNo|CustomerID|Description                      |Quantity|TotalPrice        |event_time                |
# +---------+----------+---------------------------------+--------+------------------+--------------------------+
# |538174   |12471.0   |RED TOADSTOOL LED NIGHT LIGHT    |48      |79.19999999999999 |2025-12-27 17:39:44.162687|
# |542233   |13098.0   |BREAD BIN DINER STYLE IVORY      |4       |59.8              |2025-12-27 17:39:45.162687|
# |568047   |15075.0   |BOX OF 6 MINI VINTAGE CRACKERS   |24      |59.760000000000005|2025-12-27 17:39:43.162687|
# |540834   |14733.0   |RED HANGING HEART T-LIGHT HOLDER |32      |81.6              |2025-12-27 17:39:46.162687|
# |538625   |14544.0   |CHRISTMAS HANGING HEART WITH BELL|48      |60.0              |2025-12-27 17:39:47.162687|
# +---------+----------+---------------------------------+--------+------------------+--------------------------+
#
#
# [6] Trending Items (Last Minute):
# +--------------------------------+------------------+--------------+
# |Description                     |purchase_frequency|total_quantity|
# +--------------------------------+------------------+--------------+
# |VINTAGE DOILY DELUXE SEWING KIT |2                 |5             |
# |LUNCH BAG  BLACK SKULL.         |2                 |20            |
# |BREAD BIN DINER STYLE IVORY     |2                 |6             |
# |RETROSPOT TEA SET CERAMIC 11 PC |2                 |8             |
# |PICTURE DOMINOES                |1                 |1             |
# +--------------------------------+------------------+--------------+
# only showing top 5 rows
